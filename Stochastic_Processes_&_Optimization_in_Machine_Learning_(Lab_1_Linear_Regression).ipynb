# %% [markdown]
# # Στοχαστικές Διεργασίες και Βελτιστοποίηση στη Μηχανική Μάθηση
#
# ## 1ο Εργαστήριο - Γραμμική Παλινδρόμηση
#
# - Ονομ/νυμο: Χρήστος Νίκου
# - AM: 03400146
# - Ιδιότητα: Μεταπτυχιακός φοιτητής Επιστήμης Δεδομένων και Μηχανικής Μάθησης (ΕΔΕΜΜ)
# - Ηλεκτρονική Διεύθυνση: christosnikou@mail.ntua.gr / chrisnick92@gmail.com

# %% [markdown]
# <h1><b>Ο Αλγόριθμος Γραμμικής Παλινδρόμησης (Linear Regression)</b></h1>
#
# # Εκφώνηση
#
# <p align="justify">Στην άσκηση αυτή θα μελετήσετε τον αλγόριθμο <i>γραμμικής παλινδρόμησης (linear regression)</i>, αναπτύσσοντας ένα δικό σας πρόγραμμα Python που υλοποιεί όλες τις απαραίτητες ενέργειες, χωρίς να χρησιμοποιήσετε κάποια βιβλιοθήκη της Python που υλοποιεί το μοντέλο <i>linear regression</i>, όπως είναι η <i>Scikit-Learn</i>.</p>
#
# <p align="justify">Αρχικά παρέχονται δύο αρχεία με δεδομένα εκπαίδευσης: (α) <i><a href="https://github.com/nkostopoulos/StochasticsLabPublic/blob/master/lab1/data1a.csv">data1a.csv</a></i> και (β) <i><a href="https://github.com/nkostopoulos/StochasticsLabPublic/blob/master/lab1/data1b.csv">data1b.csv</a></i>. Κάθε γραμμή του αρχείου <i>data1a.csv</i> περιλαμβάνει πληροφορίες που αφορούν τη θέαση video στο <i>YouTube</i>, όπως <i>τίτλος</i>, <i>αριθμός views</i>, <i>likes</i>, <i>dislikes</i>, κτλ. Συνολικά, το αρχείο <i>data1a.csv</i> περιλαμβάνει 11 στήλες. Περισσότερες πληροφορίες για το αρχείο <i>data1a.csv</i> μπορούν να αναζητηθούν <a href="https://www.kaggle.com/akanshasingh/us-videos-csv">εδώ</a>. Το αρχείο <i>data1b.csv</i> περιλαμβάνει 2 στήλες με επικεφαλίδες x και y αντίστοιχα. Οι τιμές αυτές δεν έχουν κάποια φυσική σημασία. Περισσότερες πληροφορίες μπορούν να βρεθούν <a href="https://www.kaggle.com/testpython/linear-regression-with-single-variable">εδώ</a>.</p>
#
# <p align="justify">Σκοπός της άσκησης είναι να αναπτύξετε ένα μοντέλο απλής (simple) <i>linear regression</i>, το οποίο θα είναι σε θέση να εκτιμά (α) για την περίπτωση του αρχείου <i>data1a.csv</i> τον αριθμό των <i>views</i> (εξαρτημένη μεταβλητή) ενός video βάσει του αριθμού των <i>likes</i> (ανεξάρτητη μεταβλητή) που αυτό έχει πάρει και (β) για την περίπτωση του αρχείου <i>data1b.csv</i> την τιμή της μεταβλητής y βάσει των τιμών της μεταβλητής x. Να αναπτύξετε ένα ενιαίο πρόγραμμα που να κάνει τα παρακάτω:</p>
# <ul>
# <li>Θα φορτώνει τα δεδομένα από τα αρχεία .csv και θα απομονώνει τις στήλες που έχουν σημασία, δηλαδή στην περίπτωση του αρχείου data1a.csv τις στήλες με επικεφαλίδες views και likes και στην περίπτωση του αρχείου data1b.csv τις στήλες με επικεφαλίδες y και x.</li>
# <li>Θα υπολογίζει τη συσχέτιση (correlation) ανάμεσα στην ανεξάρτητη και εξαρτημένη μεταβλητή των δεδομένων που παρέχονται. Το βήμα αυτό είναι απαραίτητο για να εξακριβωθεί ποιος είναι ο βαθμός γραμμικής εξάρτησης ανάμεσα στις δύο μεταβλητές. Ποιο είναι το correlation που προκύπτει στις δύο περιπτώσεις; Είναι ικανοποιητική η γραμμική εξάρτηση των δύο μεταβλητών; Για το ερώτημα αυτό να μελετήσετε την πηγή <a href="https://en.wikipedia.org/wiki/Correlation_and_dependence">εδώ</a>.</li>
# <li>Θα απεικονίζει τα σημεία που προκύπτουν ως ζεύγη της ανεξάρτητης και εξαρτημένης μεταβλητής που απομονώθηκαν στο πρώτο ερώτημα. Τι παρατηρείτε σε σχέση με τα συμπεράσματα που βγάλατε στο δεύτερο ερώτημα;</li>
# <li>Θα κανονικοποιεί τα δεδομένα που παρέχονται με τη μέθοδο min-max normalization. Περισσότερες πληροφορίες για τη μέθοδο αυτή μπορούν να βρεθούν <a href="https://en.wikipedia.org/wiki/Feature_scaling">εδώ</a>.</li>
# <li>Θα υποδιαιρεί τα δεδομένα που παρέχονται με τυχαίο τρόπο σε δύο υποσύνολα: (α) το training set που περιλαμβάνει τα δεδομένα που θα χρησιμοποιηθούν για την εκπαίδευση του μοντέλου και (β) το test set που περιλαμβάνει τα δεδομένα που θα χρησιμοποιηθούν για τον υπολογισμό της ακρίβειας του μοντέλου. Ο χρήστης θα ορίζει το ποσοστό του κάθε αρχείου σε σχέση με το αρχικό.</li>
# <li>Θα υπολογίζει τις παραμέτρους του μοντέλου linear regression, χρησιμοποιώντας τη μέθοδο Stochastic Gradient Descent (SGD). Για το σκοπό αυτό, ο χρήστης θα πρέπει να ορίζει το ρυθμό μάθησης (learning rate) και το συνολικό αριθμό των εποχών (epochs) εκπαίδευσης. Να θεωρήσετε ότι οι αρχικές τιμές των παραμέτρων είναι μηδενικές.</li>
# <li>Θα υπολογίζει το μέσο τετραγωνικό σφάλμα (mean squared error) των προβλέψεων πάνω στο test set. Περισσότερες πληροφορίες μπορούν να βρεθούν <a href="https://en.wikipedia.org/wiki/Mean_squared_error">εδώ</a>.</li>
# </ul>
#
# <p align="justify">Να θεωρήσετε ότι το test set είναι το 20% του αρχικού dataset. Τι παρατηρείτε ότι συμβαίνει στην περίπτωση που δε γίνει κανονικοποίηση των δεδομένων; Πειραματιστείτε με τις τιμές του ρυθμού μάθησης και τον αριθμό των εποχών για να δείτε πώς αλλάζει το μέσο τετραγωνικό σφάλμα.<p>

# %% [markdown]
# # Το ενιαίο πρόγραμμα - Η βασική κλάση

# %% [markdown]
# Παρακάτω δίνεται ο πηγαίος κώδικας της βασικής κλάσης που θα χρησιμοποιηθεί για την απαντήση των παραπάνω ερωτημάτων. Η λειτουργία της κάθε συνάρτησης δίνεται μαζί με την απάντηση του αντίστοιχου ερωτήματος.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # Only for better visualizations
import pandas as pd
import imageio
import os

sns.set_theme()

# %%
class linear_regressor():
    def __init__(self, data):
        self.data = data      # data is a numpy array with shape (num_samples, 2)
        self.x = data[:,0]    # first column is the independent variable
        self.y = data[:,1]    # second column is the dependent variable
        self.w = np.array([0,0]) # weights of the regression line
        self.x_norm = None
        self.y_norm = None
        
    def correlation(self):
        return np.corrcoef(self.x, self.y)[0,1]
    
    def plot(self, title = "x vs y", x = "x", y = "y", with_line = False,
             save = False, pngname = None, norm = False, path = None):
        
        if norm:
            self.x_plot, self.y_plot = self.x_norm, self.y_norm
        else:
            self.x_plot, self.y_plot = self.x, self.y
        
        fig, ax = plt.subplots(figsize = (12,8))
        ax.scatter(x = self.x_plot, y = self.y_plot)
        ax.set_xlabel(x)
        ax.set_ylabel(y)
        ax.set_title(title)
        
        if with_line:
            ax.plot(self.x_plot, np.dot(np.stack([np.array(self.x_plot.shape[0]*[1]), self.x_plot], axis = 1), self.w), 
            label = "regression line: " + f"y = {self.w[0]:.3f} + ({self.w[1]:.3f}*x)", color = "green")
            ax.legend()
        
        if save:
            plt.savefig(os.path.join(path,pngname + ".png"))
            plt.close()
        else:
            sns.set_theme()
            plt.show()
            
    def normalization(self):
        self.x_norm = (self.x - self.x.min())/(self.x.max()- self.x.min())
        self.y_norm = (self.y - self.y.min())/(self.y.max()- self.y.min())
    
    def data_splitter(self, train_ratio = 0.7, seed = 42, norm = True):
        np.random.seed(seed = seed)
        p = np.random.permutation(self.y.shape[0]) # Generate a random permutation according to seed
        point = int(train_ratio*self.y.shape[0])
        
        if norm == False:
            features, labels = self.x[p], self.y[p]
        else:
            features, labels = self.x_norm[p], self.y_norm[p]

        self.X_train, self.y_train = features[:point], labels[:point]
        self.X_test, self.y_test = features[point:], labels[point:]
        
        return self.X_train, self.y_train, self.X_test, self.y_test
    
    def fit(self, X_train, y_train, lr = 0.1, epochs = 20, seed = 42, gif = False,
            pngname = None, path = None, title = None, x_label = "x", y_label = "y"):
        np.random.seed(seed = seed)
        self.epochs = epochs
        self.lr = lr
        
        # Training starts here
        for epoch in range(self.epochs):
            p = np.random.permutation(X_train.shape[0])
            X_train, y_train = X_train[p], y_train[p]
            
            # Weight Update
            for x,y in np.array(list(zip(X_train, y_train))):
                w_new = self.w + self.lr*(y - np.dot(self.w,np.array([1,x])))*np.array([1,x])
                self.w = w_new
                
            # The following commands generate the gif file
            if gif:
                self.plot(x = x_label, y = y_label, with_line = True, save = True, norm = True,
                          path = path, title = title + str(epoch+1),
                          pngname = pngname +"-" + str((epoch+1)//10) + str(epoch+1))
    
    def predict(self, X_test):
        return self.w[0] + self.w[1]*X_test
    
    def MSE(self, X_test, y_test):
        preds = self.predict(X_test)
        return (1/len(y_test))*np.sum((y_test - preds)**2)

# %% [markdown]
# # Απαντήσεις

# %% [markdown]
# ## Ερώτημα 1
#
# > *Φορτώστε τα δεδομένα από τα αρχεία .csv και απομονώστε τις στήλες που έχουν σημασία, δηλαδή στην περίπτωση του αρχείου data1a.csv τις στήλες με επικεφαλίδες views και likes και στην περίπτωση του αρχείου data1b.csv τις στήλες με επικεφαλίδες y και x..*

# %% [markdown]
# Σε αυτό το ερώτημα φέρνουμε τα αρχεία *data1a.csv*, *data1b.csv* από τη [σελίδα](#https://github.com/nkostopoulos/StochasticsLabPublic/tree/master/lab1) του μαθήματος στο GitHub. Για κάθε δεδομένο ξεχωριστά αρχικοποιούμε ένα αντικείμενο τύπου *linear_regressor*. Με το που αρχικοποιείται το νέο αντικείμενο ο constructor της κλάσης χωρίζει το σύνολο δεδομένων χωρίζοντας την ανεξάρτητη μεταβλητή $x$ από την εξαρτημένη μεταβλητή $y$. Κάθε μια απ' τις δύο μεταβλητές αποθηκεύονται σε δύο τοπικές μεταβλητές της κλάσης εν ονόματι $x, y$ αντίστοιχα.

# %%
# Download the first dataset and keep only the important columns
datas1A = pd.read_csv('https://raw.githubusercontent.com/nkostopoulos/StochasticsLabPublic/master/lab1/data1a.csv')
datas1A = datas1A[["likes", "views"]]
datas1A
# Out:
#        likes    views
# 0     320053  4394029
# 1     185853  7860119
# 2     576597  5845909
# 3      24975  2642103
# 4      96666  1168130
# ...      ...      ...
# 7991   14362   440393
# 7992    1265    55762
# 7993    7088   142908
# 7994    2148    24532
# 7995    1574   144039
#
# [7996 rows x 2 columns]

# %%
# Download the second dataset
datas1B = pd.read_csv('https://raw.githubusercontent.com/nkostopoulos/StochasticsLabPublic/master/lab1/data1b.csv')
datas1B
# Out:
#       x          y
# 0    24  21.549452
# 1    50  47.464463
# 2    15  17.218656
# 3    38  36.586398
# 4    87  87.288984
# ..   ..        ...
# 994  71  68.545888
# 995  46  47.334876
# 996  55  54.090637
# 997  62  63.297171
# 998  47  52.459467
#
# [999 rows x 2 columns]

# %%
# Initialize two new linear_regressor objects, one for each dataset

lmA = linear_regressor(datas1A.to_numpy())
lmB = linear_regressor(datas1B.to_numpy())

# %% [markdown]
# Έχοντας αρχικοποιήσει τις δύο κλάσεις τύπου *linear_regressor* μπορούμε για κάθε σύνολο δεδομένων ξεχωριστά να δούμε το διάνυσμα που αντιστοιχεί στην ανεξάρτητη μεταβλητή και στην εξαρτημένη μεταβλητή. Παρακάτω δίνουμε ένα παράδειγμα για το σύνολο δεδομένων που αφορά την πρόβλεψη του αριθμού των views ενός βίντεο μέσω των likes.

# %%
print(f"- The data points of indepedent variable is: {lmA.x}")
print(f"- The data points of the dependent variable is: {lmA.y}")
# Out:
# - The data points of indepedent variable is: [320053 185853 576597 ...   7088   2148   1574]
# - The data points of the dependent variable is: [4394029 7860119 5845909 ...  142908   24532  144039]

# %% [markdown]
# ## Ερώτημα 2
#
# > *Υπολογίστε τη συσχέτιση (correlation) ανάμεσα στην ανεξάρτητη και εξαρτημένη μεταβλητή των δεδομένων που παρέχονται. Το βήμα αυτό είναι απαραίτητο για να εξακριβωθεί ποιος είναι ο βαθμός γραμμικής εξάρτησης ανάμεσα στις δύο μεταβλητές. Ποιο είναι το correlation που προκύπτει στις δύο περιπτώσεις; Είναι ικανοποιητική η γραμμική εξάρτηση των δύο μεταβλητών; Για το ερώτημα αυτό να μελετήσετε την πηγή [εδώ](#https://en.wikipedia.org/wiki/Correlation).*

# %% [markdown]
# Για να υπολογίσουμε τη συσχέτιση (correlation) ανάμεσα στην ανεξάρτητη και εξαρτημένη μεταβλητή των δεδομένων χρησιμοποιούμε τη συνάρτηση *correlation* της κλάσης *linear_regressor*. Παρακάτω δίνουμε τον συντελεστή συσχέτισης της ανεξερτήτης μεταβλητής και της εξαρτημένης μεταβλητής για τα δύο σύνολα δεδομένων. Τέλος, εξηγούμε πως προκύπτει ο συντελεστής συσχέτισης και δίνουμε ερμηνείες για τα αποτελέσματα που παίρνουμε απ' τους δύο υπολογισμούς.

# %%
print(f"- The correlation between the independent variable (likes) and the dependent variable (views) is: {lmA.correlation():.3f}")
print(f"- The correlation between the independent variable (x) and the dependent variable (y) is: {lmB.correlation():.3f}")
# Out:
# - The correlation between the independent variable (likes) and the dependent variable (views) is: 0.833
# - The correlation between the independent variable (x) and the dependent variable (y) is: 0.995

# %% [markdown]
# Όπως βλέπουμε ο συντελεστής συσχέτισης μεταξύ του αριθμού των likes και του αριθμού των views είναι 0.833 και ο συντελεστής συσχέτισης της ανεξάρτητης μεταβλητής x και της εξαρτημένης μεταβλητής y για το δεύτερο σύνολο δεδομένων είναι 0.995. Και οι δύο παραπάνω τιμές είναι ιδιαίτερα ικανοποιητικές για να θεωρήσουμε ότι υπάρχει έντονη γραμμική εξάρτηση (συσχέτιση) μεταξύ της ανεξάρτητης και της εξαρτημένης μεταβλητής.
#
# Ο συντελεστής συσχέτισης κατά Pearson $r_{xy}$ για δύο διανύσματα $x = (x_1,\dots,x_n),\, y = (y_1,\dots,y_n)$ δίνεται από τη σχέση
# $$\tag{2.1} r_{xy} = \frac{\sum_{i=1}^n(x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum_{i=1}^n(x_i- \bar{x})^2}\cdot \sqrt{\sum_{i=1}^n (y_i - \bar{y})^2}},$$
# όπου $\bar{x},\bar{y}$ ο δειγματικός μέσος των δύο διανυσμάτων $x,y$. Ο συντελεστής συσχέτισης ικανοποιεί την ανίσωση $-1\leq r_{x,y}\leq 1$. Τιμές που βρίσκονται κοντά στα "άκρα" ($\pm 1$) υποδεικνύουν έντονη γραμμική εξάρτηση μεταξύ των τιμών του διανύσματος $x$ και των αντίστοιχων τιμών του διανύσματος $y$. Αν η τιμή βρίσκεται κοντά στο $1$, τότε έχουμε υψηλή γραμμική θετική γραμμική εξάρτηση, δηλαδή, όσο αυξάνουν οι τιμές του $x$ αναμένουμε να δούμε και αντίστοιχη αύξηση στις τιμές του διανύσματος $y$. Αντιθέτως, τιμές κοντά στο $-1$ υποδηλώνουν έντονη αρνητική γραμμική εξάρτηση, το οποίο σημαίνει ότι όσο αυξάνονται οι τιμές του διανύσματος $x$ αναμένουμε να δούμε ανάλογη μείωση των τιμών του διανύσματος $y$.

# %% [markdown]
# ## Ερώτημα 3
#
# > *Απεικονίστε τα σημεία που προκύπτουν ως ζεύγη της ανεξάρτητης και εξαρτημένης μεταβλητής που απομονώθηκαν στο πρώτο ερώτημα. Τι παρατηρείτε σε σχέση με τα συμπεράσματα που βγάλατε στο δεύτερο ερώτημα;*

# %% [markdown]
# Χρησιμοποιώντας τη συνάρτηση *plot* της κλάσης *linear_regressor* απεικονίζουμε τα σημεία των δύο δεδομένων στο επίπεδο. Στον άξονα των $y$ έχουμε την εξαρτημένη μεταβλητή και στον άξονα των $x$ την εξαρτημένη μεταβλητή.

# %%
lmA.plot(title = "Likes vs Views", x ="Likes", y = "Views")

# %%
lmB.plot(title = "x vs y")

# %% [markdown]
# Αυτό που παρατηρούμε στο πρώτα σχήμα είναι πως υπάρχει κάποια γραμμική εξάρτηση μεταξύ του αριθμού των likes ενός βίντεο και του αριθμού των views. Αυτό βέβαια ήταν κάτι το οποίο το περιμέναμε αφού στο Ερώτημα 3 υπολογίσαμε ότι ο συντελεστής συσχέτισης των δύο μεταβλητών είναι $0.833$. Στη δεύτερη περίπτωση η γραμμική εξάρτηση είναι αρκετά πιο εμφανής από την πρώτη περίπτωση, αποτέλεσμα το οποίο το αναμέναμε αφού ο συντελεστής συσχέτισης για αυτές τις δύο μεταβλητές είναι $0.995$.

# %% [markdown]
# ## Ερώτημα 4
#
# > *Κανονικοποιήστε τα δεδομένα που παρέχονται με τη μέθοδο min-max normalization. Περισσότερες πληροφορίες για τη μέθοδο αυτή μπορούν να βρεθούν [εδώ](#https://en.wikipedia.org/wiki/Feature_scaling).*

# %% [markdown]
# Σε αυτό το σημείο μέσω της συνάρτησης *normalization*, η οποία υλοποιείται μέσω της βασική μας κλάσης, κανονικοποιούμε τα δεδομένα μέσω της μεθόδου *min-max normalization*. Η μέθοδος αυτή συνοψίζεται ως εξής: Αν $x = (x_1,\dots,x_n)$ είναι ένα διάνυσμα πραγματικών αριθμών, τότε η μέθοδος επιστρέφει ένα διάνυσμα $x' = (x_1',\dots,x_n')$, όπου
# $$\tag{4.1} x_i' = \frac{\max\limits_{1\leq i \leq n}{x_i} - x_i}{\max\limits_{1\leq i \leq n} x_i - \min\limits_{1\leq i \leq n}x_i}.$$

# %% [markdown]
# Παρακάτω βλέπουμε τα κανονικοποιήμενα δεδομένα που προκύπτουν από τα δεδομένα του 1ου dataset που αφορά τα βίντεο στο YouTube.

# %%
lmA.normalization()
print("------> Independent variable <------")
print(f"- The raw data of the independent variable for the YouTube videos are: {lmA.x}")
print(f"- After normalization the data are: {lmA.x_norm}")
print("\n\n------> Dependent variable <------")
print(f"- The raw data of the independent variable for the YouTube videos are: {lmA.y}")
print(f"- After normalization the data are: {lmA.y_norm}")
# Out:
# ------> Independent variable <------
# - The raw data of the independent variable for the YouTube videos are: [320053 185853 576597 ...   7088   2148   1574]
# - After normalization the data are: [0.15920136 0.09244735 0.28681195 ... 0.00352573 0.00106846 0.00078294]
#
#
# ------> Dependent variable <------
# - The raw data of the independent variable for the YouTube videos are: [4394029 7860119 5845909 ...  142908   24532  144039]
# - After normalization the data are: [0.1058785  0.18939739 0.140863   ... 0.00344351 0.00059112 0.00347076]

# %% [markdown]
# Παρακάτω βλέπουμε και τις αντίστοιχες μετατροπές για το δεύτερο σύνολο δεδομένων.

# %%
#  2.61999623e-01 5.08913054e-01 1.96554293e-01 2.24168223e-01
#  3.03899635e-01 6.34552282e-01 1.85654888e-01 5.74545198e-01
#  1.67109015e-01 1.82671709e-01 4.01992521e-01 4.14200867e-01
#  5.58674628e-01 8.44177692e-01 1.11020672e-01 3.82878375e-01
#  8.12131792e-02 8.20252901e-02 6.42222002e-01 4.54033637e-01
#  5.13972105e-01 5.95654325e-01 4.99500036e-01]

# %% [markdown]
# Παρακάτω βλέπουμε και την απείκονιση των δεδομένων μετά την *max-min* κανονικοποίηση. Ο τρόπος με τον οποίο απεικονίζουμε τα κανονικοποιημένα γίνεται μέσω της λογικής παραμέτρου *norm* της συνάρτησης *plot*. Θέτοντας την παραμέτρο αυτή σε *True* η συνάρτηση χρησιμοποιεί τα κανονικοποιημένα δεδομένα αντί των αρχικών δεδομένων.

# %%
lmA.plot(title = "Likes vs Views", norm = True)

# %%
lmB.plot(title = "x vs y", norm = True)

# %% [markdown]
# ## Ερώτημα 5
#
# > *Χωρίστε τα δεδομένα που παρέχονται με τυχαίο τρόπο σε δύο υποσύνολα: (α) το training set που περιλαμβάνει τα δεδομένα που θα χρησιμοποιηθούν για την εκπαίδευση του μοντέλου και (β) το test set που περιλαμβάνει τα δεδομένα που θα χρησιμοποιηθούν για τον υπολογισμό της ακρίβειας του μοντέλου. Ο χρήστης θα ορίζει το ποσοστό του κάθε αρχείου σε σχέση με το αρχικό.*

# %% [markdown]
# Ο χωρισμός των δεδομένων σε *train* και *test* set γίνεται μέσω της συνάρτησης *data_splitter* της βασικής κλάσης. Η συνάρτηση δέχεται ως παραμέτρο το ποσοστό του συνολικού dataset που θέλουμε να έχει ως μέγεθος το σύνολο εκπαίδευσης. Με τις επόμενες εντολές χωρίζουμε το σύνολο των δεδομένων που αφορά τα βίντεο του YouTube με ποσοστό 0.8 για το σύνολο εκπαίδευσης και 0.2 για το σύνολο δεδομένων. Για το δεύτερο σύνολο δεδομένων χρησιμοποιούμε επίσης ποσοστό 0.8 για το σύνολο εκπαίδευσης και το υπόλοιπο 0.2 για το σύνολο ελέγχου.

# %%
X_trainA, y_trainA, X_testA, y_testA = lmA.data_splitter(train_ratio = 0.8)

# %%
print(f"- The size of the initial data set is {lmA.x.shape[0]} and the size of the training set after splitting is {X_trainA.shape[0]}")
print(f"- The ratio is {X_trainA.shape[0]/lmA.x.shape[0]:.2f}.")
# Out:
# - The size of the initial data set is 7996 and the size of the training set after splitting is 6396
# - The ratio is 0.80.

# %%
X_trainB, y_trainB, X_testB, y_testB = lmB.data_splitter(train_ratio = 0.8)

# %%
print(f"- The size of the initial data set is {lmB.x.shape[0]} and the size of the training set after splitting is {X_trainB.shape[0]}")
print(f"- The ratio is {X_trainB.shape[0]/lmB.x.shape[0]:.2f}.")
# Out:
# - The size of the initial data set is 999 and the size of the training set after splitting is 799
# - The ratio is 0.80.

# %% [markdown]
# ## Ερώτημα 6
#
# > *Υπολογίστε τις παραμέτρους του μοντέλου linear regression, χρησιμοποιώντας τη μέθοδο Stochastic Gradient Descent (SGD). Για το σκοπό αυτό, ο χρήστης θα πρέπει να ορίζει το ρυθμό μάθησης (learning rate) και το συνολικό αριθμό των εποχών (epochs) εκπαίδευσης. Να θεωρήσετε ότι οι αρχικές τιμές των παραμέτρων είναι μηδενικές.*

# %% [markdown]
# Η εκτίμηση των παραμέτρων του μοντέλου *linear_regression* με τη μέθοδο *Stochastic Gradient Descent (SGD)* υλοποιείται μέσω της συνάρτησης *fit* της βασικής κλάσης. Η συνάρτηση δέχεται ως παραμέτρους τα χαρακτηριστικά του συνόλου εκπαίδευσης (`X_train`), τις ταμπέλες που αντιστοιχούν στο σύνολο εκπαίδευσης (`y_train`), τον ρυθμό εκμάθησης (`lr`), το σύνολο των εποχών (`epochs`) και το φίτρο (`seed`) που αντιστοιχεί στην τυχαία αρχικοποιήση για το ανακάτεμα του συνόλου εκπαίδευσης πριν από κάθε εποχή.
#
# Η μέθοδος λειτουργεί ως εξής: Αρχικά πριν την είσοδο σε μια νεα εποχή το σύνολο εκπαίδευσης ανακατεύεται με τυχαίο τρόπο. Ύστερα, περνώντας ένα - ένα τα δεδομένα η ανανέωση των βαρών απ' το δεδομένο $i$ στο $i+1$ γίνεται με βάση την εξίσωση
# $$\tag{6.1} w_{i+1} = w_i + lr\cdot \bigl(y_i - w_i^T\cdot [1,x_i]\bigr)\cdot [1,x_i],$$
# όπου $w_i$ είναι το διάνυσμα βαρών στην $i-$οστή επανάληψη, $x_i$ είναι η τιμή που αντιστοιχεί στην ανεξάρτητη μεταβλητή της $i$-οστής παρατήρησης (μετά το ανακάτεμα), $y_i$ είναι η τιμή της εξαρτημένης μεταβλητής και $lr$ είναι ο ρυθμός εκμάθησης. Παρακάτω βλέπουμε το διάνυσμα βαρών μετά την εκτίμηση των παραμέτρων για ρυθμό εκμάθησης $0.1$ και $20$ εποχές. Επίσης, βλέπουμε και ένα σχήμα με τα δεδομένα και την αντίστοιχη προσαρμοσμένη ευθεία μετά την εκτίμηση των παραμέτρων.

# %%
# 1st Dataset - YouTube videos

print(f"- Before training the weight vector is: {lmA.w}")

lmA.fit(X_trainA, y_trainA, lr = 0.1, epochs = 20)

print(f"- After training for {lmA.epochs} epochs with learning rate {lmA.lr} the weight vector is {lmA.w}")
# Out:
# - Before training the weight vector is: [0 0]
# - After training for 20 epochs with learning rate 0.1 the weight vector is [0.00560273 0.92075403]

# %%
lmA.plot(title = "Likes vs Views", x ="Likes", y = "Views", with_line = True, norm = True)

# %%
# 2nd Dataset 

print(f"- Before training the weight vector is: {lmB.w}")

lmB.fit(X_trainB, y_trainB, lr = 0.1, epochs = 20)

print(f"- After training for {lmB.epochs} epochs with learning rate {lmB.lr} the weight vector is {lmB.w}")
# Out:
# - Before training the weight vector is: [0 0]
# - After training for 20 epochs with learning rate 0.1 the weight vector is [0.02989396 0.88998233]

# %%
lmB.plot(title = "x vs y", with_line = True, norm = True)

# %% [markdown]
# Χρησιμοποιώντας τη συνάρτηση *generate_line_gif* (βλ. Βοηθητικός Κώδικας) μπορούμε να φτιάξουμε ένα αρχείο *gif* το οποίο να μας δείχνει τη μεταβολή της ευθείας ανάλογα με την ανανέωση των παραμέτρων στο τέλος της κάθε εποχής. Παρακάτω βλέπουμε πως μεταβάλλεται η ευθεία για το πρώτο σύνολο δεδομένων με τα βίντεο του YouTube για $80$ εποχές και ρυθμό μάθησης $0.005$ αλλά και τις αντίστοιχες εντολές που παράγουν το αρχείο *gif*.

# %% [markdown]
# `generate_line_gif(datas1A.to_numpy(), title = "Regression line in epoch ", pngname = "Datas1A",
#                  x = "Likes", y = "Views", lr = 0.005, epochs =80, fps =2)`

# %% [markdown]
# ### 6.1 Η μεταβολή της προσαρμοσμένης ευθείας στο τέλος κάθε εποχής - YouTube Dataset.

# %%
from IPython.display import Image
Image("Datas1A.gif")

# %% [markdown]
# Παρακάτω βλέπουμε τις εντολές και το αντίστοιχο σχήμα για το δεύτερο σύνολο δεδομένων για $30$ εποχές και με ρυθμό εκμάθησης $0.005$.
#
# `generate_line_gif(datas1B.to_numpy(), title = "Regression line in epoch ", pngname = "Datas1B",
#                  x = "x", y = "y", lr = 0.005, epochs =30, fps =2)`

# %% [markdown]
# ### 6.2 Η μεταβολή της προσαρμοσμένης ευθείας στο τέλος κάθε εποχής - 2ο Dataset.

# %%
Image("Datas1B.gif")

# %% [markdown]
# ## Ερώτημα 7
#
# > *Θα υπολογίστε το μέσο τετραγωνικό σφάλμα (mean squared error) των προβλέψεων πάνω στο test set. Περισσότερες πληροφορίες μπορούν να βρεθούν [εδώ](#https://en.wikipedia.org/wiki/Mean_squared_error).*

# %% [markdown]
# Σε αυτό το σημείο έχοντας υπολογίσει τις παραμέτρους των δύο ευθειών για τα δύο σύνολα δεδομένων υπολογίζουμε το μέσο τετραγωνικό σφάλμα το οποίο μας δίνει ένα κριτήριο αξιολόγησης των δύο μοντέλων. Αν συμβολίζουμε με $y = (y_1,\dots,y_n)$ το διάνυσμα των πραγματικών τιμών (*true labels*) και με $\hat{y} = (\hat{y_1},\dots,\hat{y_n})$ το διάνυσμα των προβλέψεων (*predicted labels*), τότε το μέσο τετραγωνικό σφάλμα δίνεται από τη σχέση
# $$\tag{7.1} MSE(y,\hat{y}) = \frac{1}{n}\sum_{i=1}^n(y_i - \hat{y_i})^2.$$

# %%
print(f"- The mean square error for the YouTube dataset is: {lmA.MSE(X_testA, y_testA):.8f}")
print(f"- The mean square error for the second dataset is: {lmB.MSE(X_testB, y_testB):.8f}")
# Out:
# - The mean square error for the YouTube dataset is: 0.00085923
# - The mean square error for the second dataset is: 0.00061427

# %% [markdown]
# ## Ερώτημα 8
#
# > *Τι παρατηρείτε ότι συμβαίνει στην περίπτωση που δε γίνει κανονικοποίηση των δεδομένων; Πειραματιστείτε με τις τιμές του ρυθμού μάθησης και τον αριθμό των εποχών για να δείτε πώς αλλάζει το μέσο τετραγωνικό σφάλμα.*

# %% [markdown]
# Όπως παρατηρούμε παρακάτω αν δε γίνει κανονικοποίηση των δεδομένων, εξαιτίας των μεγάλων τιμών που έχουν τα δεδομένα δεν μπορεί να υπολογιστούν επακριβώς οι παράμετροι του μοντέλου μας λόγω της υπερχείλισης που γίνεται.

# %%
lmA2 = linear_regressor(datas1A.to_numpy())

X_trainA, y_trainA, X_testA, y_testA = lmA2.data_splitter(train_ratio = 0.8, norm = False)

lmA2.fit(X_trainA, y_trainA, lr = 0.01, epochs = 30)

print(f"- The weight vector after training for {lmA2.epochs} with learning rate {lmA2.lr} is: {lmA2.w}")
# Out:
# C:\Users\DEM0NA~1\AppData\Local\Temp/ipykernel_1252/503638401.py:71: RuntimeWarning: invalid value encountered in add
#   w_new = self.w + self.lr*(y - np.dot(self.w,np.array([1,x])))*np.array([1,x])
# - The weight vector after training for 30 with learning rate 0.01 is: [nan nan]

# %% [markdown]
# Παρακάτω πειραματιζόμαστε με διάφορες τιμές του ρυθμού μάθησης και του αριθμού των εποχών και βλέπουμε την επίπτωση που έχουν αυτές οι αλλαγές υπολογίζοντας το μέσο τετραγωνικό σφάλμα.

# %%
learning_rates = [1, 0.8 , 0.1, 0.5, 0.01, 0.001, 0.05]
num_epochs = [5, 10, 15, 20, 25, 30, 50, 60, 70, 80, 90, 100]

for lr in learning_rates:
    for epochs in num_epochs:
        lm = linear_regressor(datas1A.to_numpy())
        lm.normalization()
        X_trainA, y_trainA, X_testA, y_testA = lm.data_splitter(train_ratio = 0.8)
        
        lm.fit(X_trainA, y_trainA, lr = lr, epochs = epochs)
        print(f"- Epochs: {epochs}, Learning rate: {lr}, MSE Loss: {lm.MSE(X_testA, y_testA)}")
# Out:
# - Epochs: 5, Learning rate: 1, MSE Loss: 0.0009389384434777507
# - Epochs: 10, Learning rate: 1, MSE Loss: 0.0012714428765095106
# - Epochs: 15, Learning rate: 1, MSE Loss: 0.0010513188009282966
# - Epochs: 20, Learning rate: 1, MSE Loss: 0.000897039820596189
# - Epochs: 25, Learning rate: 1, MSE Loss: 0.0008992969495166441
# - Epochs: 30, Learning rate: 1, MSE Loss: 0.000928453915791253
# - Epochs: 50, Learning rate: 1, MSE Loss: 0.0008790373190671366
# - Epochs: 60, Learning rate: 1, MSE Loss: 0.001898731729056376
# - Epochs: 70, Learning rate: 1, MSE Loss: 0.0010947754855243417
# - Epochs: 80, Learning rate: 1, MSE Loss: 0.001164133873733634
# - Epochs: 90, Learning rate: 1, MSE Loss: 0.0009550767075381886
# - Epochs: 100, Learning rate: 1, MSE Loss: 0.0016996621517756676
# - Epochs: 5, Learning rate: 0.8, MSE Loss: 0.0009374768690765564
# - Epochs: 10, Learning rate: 0.8, MSE Loss: 0.0011317153914059562
# - Epochs: 15, Learning rate: 0.8, MSE Loss: 0.0009940686065427608
# - Epochs: 20, Learning rate: 0.8, MSE Loss: 0.000938723541381743
# - Epochs: 25, Learning rate: 0.8, MSE Loss: 0.0008644218322879371
# - Epochs: 30, Learning rate: 0.8, MSE Loss: 0.0009049074731816477
# - Epochs: 50, Learning rate: 0.8, MSE Loss: 0.0008823788585559716
# - Epochs: 60, Learning rate: 0.8, MSE Loss: 0.0017552436291482902
# - Epochs: 70, Learning rate: 0.8, MSE Loss: 0.0010525859821747339
# - Epochs: 80, Learning rate: 0.8, MSE Loss: 0.0011111187240096779
# - Epochs: 90, Learning rate: 0.8, MSE Loss: 0.0009391878902349685
# - Epochs: 100, Learning rate: 0.8, MSE Loss: 0.0013948867559455548
# - Epochs: 5, Learning rate: 0.1, MSE Loss: 0.0008879496025426301
# - Epochs: 10, Learning rate: 0.1, MSE Loss: 0.0008594693821086096
# - Epochs: 15, Learning rate: 0.1, MSE Loss: 0.000875246735246386
# - Epochs: 20, Learning rate: 0.1, MSE Loss: 0.0008592274256914568
# - Epochs: 25, Learning rate: 0.1, MSE Loss: 0.0008720811425063724
# - Epochs: 30, Learning rate: 0.1, MSE Loss: 0.0008587511974390521
# - Epochs: 50, Learning rate: 0.1, MSE Loss: 0.0008632857724514107
# - Epochs: 60, Learning rate: 0.1, MSE Loss: 0.0008941124563088751
# - Epochs: 70, Learning rate: 0.1, MSE Loss: 0.0008889490929933769
# - Epochs: 80, Learning rate: 0.1, MSE Loss: 0.0008887496942535124
# - Epochs: 90, Learning rate: 0.1, MSE Loss: 0.0008658091699354937
# - Epochs: 100, Learning rate: 0.1, MSE Loss: 0.0008563812143976927
# - Epochs: 5, Learning rate: 0.5, MSE Loss: 0.000944220044910966
# - Epochs: 10, Learning rate: 0.5, MSE Loss: 0.000967120815704011
# - Epochs: 15, Learning rate: 0.5, MSE Loss: 0.0009309977511630319
# - Epochs: 20, Learning rate: 0.5, MSE Loss: 0.0009438882502680307
# - Epochs: 25, Learning rate: 0.5, MSE Loss: 0.0008532448989989388
# - Epochs: 30, Learning rate: 0.5, MSE Loss: 0.0008882854436863938
# - Epochs: 50, Learning rate: 0.5, MSE Loss: 0.0008933737828708567
# - Epochs: 60, Learning rate: 0.5, MSE Loss: 0.0013856627989162075
# - Epochs: 70, Learning rate: 0.5, MSE Loss: 0.00098943277810831
# - Epochs: 80, Learning rate: 0.5, MSE Loss: 0.0010158744066451045
# - Epochs: 90, Learning rate: 0.5, MSE Loss: 0.000895453255490953
# - Epochs: 100, Learning rate: 0.5, MSE Loss: 0.001067439949170285
# - Epochs: 5, Learning rate: 0.01, MSE Loss: 0.0013911501472890565
# - Epochs: 10, Learning rate: 0.01, MSE Loss: 0.0010446381680090254
# - Epochs: 15, Learning rate: 0.01, MSE Loss: 0.0009210900179033194
# - Epochs: 20, Learning rate: 0.01, MSE Loss: 0.00088156104695254
# - Epochs: 25, Learning rate: 0.01, MSE Loss: 0.0008883553907364261
# - Epochs: 30, Learning rate: 0.01, MSE Loss: 0.0008597292756022985
# - Epochs: 50, Learning rate: 0.01, MSE Loss: 0.0008531793978186233
# - Epochs: 60, Learning rate: 0.01, MSE Loss: 0.0008563296917109316
# - Epochs: 70, Learning rate: 0.01, MSE Loss: 0.0008614066566088399
# - Epochs: 80, Learning rate: 0.01, MSE Loss: 0.0008595201324560226
# - Epochs: 90, Learning rate: 0.01, MSE Loss: 0.0008569592707726783
# - Epochs: 100, Learning rate: 0.01, MSE Loss: 0.0008550368138940487
# - Epochs: 5, Learning rate: 0.001, MSE Loss: 0.0024308277812989916
# - Epochs: 10, Learning rate: 0.001, MSE Loss: 0.0022497452740892383
# - Epochs: 15, Learning rate: 0.001, MSE Loss: 0.002087014622245246
# - Epochs: 20, Learning rate: 0.001, MSE Loss: 0.0019469975673150767
# - Epochs: 25, Learning rate: 0.001, MSE Loss: 0.0018268915650981625
# - Epochs: 30, Learning rate: 0.001, MSE Loss: 0.0017121297290748118
# - Epochs: 50, Learning rate: 0.001, MSE Loss: 0.0013903561219989209
# - Epochs: 60, Learning rate: 0.001, MSE Loss: 0.0012809592625587106
# - Epochs: 70, Learning rate: 0.001, MSE Loss: 0.0011955123386971995
# - Epochs: 80, Learning rate: 0.001, MSE Loss: 0.0011292051273639333
# - Epochs: 90, Learning rate: 0.001, MSE Loss: 0.0010745143830070134
# - Epochs: 100, Learning rate: 0.001, MSE Loss: 0.0010325840919618641
# - Epochs: 5, Learning rate: 0.05, MSE Loss: 0.0008799965961844399
# - Epochs: 10, Learning rate: 0.05, MSE Loss: 0.0008609282547767363
# - Epochs: 15, Learning rate: 0.05, MSE Loss: 0.0008618463361465102
# - Epochs: 20, Learning rate: 0.05, MSE Loss: 0.0008570535785512236
# - Epochs: 25, Learning rate: 0.05, MSE Loss: 0.0008503155888768993
# - Epochs: 30, Learning rate: 0.05, MSE Loss: 0.0008549580471381981
# - Epochs: 50, Learning rate: 0.05, MSE Loss: 0.000858458654733628
# - Epochs: 60, Learning rate: 0.05, MSE Loss: 0.0008689946641205998
# - Epochs: 70, Learning rate: 0.05, MSE Loss: 0.0008802619168756248
# - Epochs: 80, Learning rate: 0.05, MSE Loss: 0.0008802183017932215
# - Epochs: 90, Learning rate: 0.05, MSE Loss: 0.0008542171732110751
# - Epochs: 100, Learning rate: 0.05, MSE Loss: 0.0008525852968141429

# %% [markdown]
# # Βοηθητικός Κώδικας

# %%
import imageio
import os

def generate_line_gif(data, title, pngname, fps = 1, 
                      filename = "TempFile", epochs = 20, lr = 0.1, split_ratio = 0.7,
                     x = "x", y = "y"):
    
    regressor = linear_regressor(data)
    
    try:
        # Create Directory
        path = os.getcwd()
        os.mkdir(filename)
        print("Directory" , filename ,  "Created ")
        
        regressor.normalization()
        X_train, y_train, X_test, y_test = regressor.data_splitter(train_ratio = split_ratio)
        regressor.fit(X_train, y_train, lr = lr, epochs = epochs,
                     gif = True, x_label = x, y_label = y, pngname = pngname, path = os.path.join(os.path.join(path, filename)),
                     title = title)
        
        png_dir = os.path.join(path, filename)
        images = []
        for file_name in sorted(os.listdir(png_dir)):
            if file_name.endswith('.png'):
                file_path = os.path.join(png_dir, file_name)
                images.append(imageio.imread(file_path))
        imageio.mimsave(pngname +".gif", images, fps = fps)
        
      # Remove the specified  
      # file path
        names = os.listdir(png_dir)
        for fname in sorted(names, key=lambda x:int(x.split('-')[-1].split('.')[0])):
            png_path = os.path.join(path, png_dir)
            if fname.endswith(".png"):
                os.remove(os.path.join(png_path, fname))
        try: 
            os.rmdir(filename) 
            print("% s removed successfully" % os.path.join(path, filename))
        except OSError as error: 
            print(error) 
            print("File path can not be removed") 
            
    except FileExistsError:
        print("Directory " , filename ,  " already exists")
